# %% [markdown]
# <a href="https://colab.research.google.com/github/jasmeenshaik05/IBM-ANALYSISOFSUPERSTORE/blob/main/Project_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Load the dataset**

# %%
df=pd.read_csv("SampleSuperstore.csv")

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# **understanding data**

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %% [markdown]
# **statistical** **description**

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %% [markdown]
# seeing the unique values

# %%
df["Ship Mode"].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %%
df["Ship Mode"].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
df["Segment"].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
df["Segment"].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
df["City"].unique()
# Out:
# array(['Henderson', 'Los Angeles', 'Fort Lauderdale', 'Concord',
#        'Seattle', 'Fort Worth', 'Madison', 'West Jordan', 'San Francisco',
#        'Fremont', 'Philadelphia', 'Orem', 'Houston', 'Richardson',
#        'Naperville', 'Melbourne', 'Eagan', 'Westland', 'Dover',
#        'New Albany', 'New York City', 'Troy', 'Chicago', 'Gilbert',
#        'Springfield', 'Jackson', 'Memphis', 'Decatur', 'Durham',
#        'Columbia', 'Rochester', 'Minneapolis', 'Portland', 'Saint Paul',
#        'Aurora', 'Charlotte', 'Orland Park', 'Urbandale', 'Columbus',
#        'Bristol', 'Wilmington', 'Bloomington', 'Phoenix', 'Roseville',
#        'Independence', 'Pasadena', 'Newark', 'Franklin', 'Scottsdale',
#        'San Jose', 'Edmond', 'Carlsbad', 'San Antonio', 'Monroe',
#        'Fairfield', 'Grand Prairie', 'Redlands', 'Hamilton', 'Westfield',
#        'Akron', 'Denver', 'Dallas', 'Whittier', 'Saginaw', 'Medina',
#        'Dublin', 'Detroit', 'Tampa', 'Santa Clara', 'Lakeville',
# ...

# %%
df["City"].value_counts()
# Out:
# New York City      915
# Los Angeles        747
# Philadelphia       537
# San Francisco      510
# Seattle            428
#                   ...
# Glenview             1
# Missouri City        1
# Rochester Hills      1
# Palatine             1
# Manhattan            1
# Name: City, Length: 531, dtype: int64

# %%
df["Category"].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
df["Category"].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
df['Sub-Category'].value_counts()
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
df["Region"].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
df['State'].unique()
# Out:
# array(['Kentucky', 'California', 'Florida', 'North Carolina',
#        'Washington', 'Texas', 'Wisconsin', 'Utah', 'Nebraska',
#        'Pennsylvania', 'Illinois', 'Minnesota', 'Michigan', 'Delaware',
#        'Indiana', 'New York', 'Arizona', 'Virginia', 'Tennessee',
#        'Alabama', 'South Carolina', 'Oregon', 'Colorado', 'Iowa', 'Ohio',
#        'Missouri', 'Oklahoma', 'New Mexico', 'Louisiana', 'Connecticut',
#        'New Jersey', 'Massachusetts', 'Georgia', 'Nevada', 'Rhode Island',
#        'Mississippi', 'Arkansas', 'Montana', 'New Hampshire', 'Maryland',
#        'District of Columbia', 'Kansas', 'Vermont', 'Maine',
#        'South Dakota', 'Idaho', 'North Dakota', 'Wyoming',
#        'West Virginia'], dtype=object)

# %%
average_sales = np.mean(df['Sales'])
print('Average Sales:', average_sales)
# Out:
# Average Sales: 229.85800083049833

# %%
total_profit = np.sum(df['Profit'])
print('Total Profit:', total_profit)
# Out:
# Total Profit: 286397.0217

# %%
max_quantity = np.max(df['Quantity'])
print('Maximum Quantity:', max_quantity)
# Out:
# Maximum Quantity: 14

# %%
min_discount = np.min(df['Discount'])
print('Minimum Discount:', min_discount)
# Out:
# Minimum Discount: 0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [markdown]
# **Data cleaning**

# %%
store_df=pd.DataFrame(df)
store_df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
store_df=df.drop(columns=['Postal Code'],axis=1)

# %%
print(store_df.dtypes)
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
# Check if there are any missing values in the dataset

print(store_df.isnull().sum())
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
# Calculate summary statistics to identify outliers
print(store_df.describe())
# Out:
#               Sales     Quantity     Discount       Profit
# count   9994.000000  9994.000000  9994.000000  9994.000000
# mean     229.858001     3.789574     0.156203    28.656896
# std      623.245101     2.225110     0.206452   234.260108
# min        0.444000     1.000000     0.000000 -6599.978000
# 25%       17.280000     2.000000     0.000000     1.728750
# 50%       54.490000     3.000000     0.200000     8.666500
# 75%      209.940000     5.000000     0.200000    29.364000
# max    22638.480000    14.000000     0.800000  8399.976000

# %%
# Calculate basic statistics
mean_sales = store_df['Sales'].mean()
median_Sales = store_df['Sales'].median()
max_Sales = store_df['Sales'].max()
min_Sales = store_df['Sales'].min()
print('Mean Sales:', mean_sales)
print('Median Sales:', median_Sales)
print('Maximum Sales:', max_Sales)
print('Minimum Sales:', min_Sales)
# Out:
# Mean Sales: 229.85800083049833
# Median Sales: 54.489999999999995
# Maximum Sales: 22638.48
# Minimum Sales: 0.444

# %%
mean_Profit = store_df['Profit'].mean()
median_Profit = store_df['Profit'].median()
max_Profit = store_df['Profit'].max()
min_Profit = store_df['Profit'].min()
print('Mean Profit:', mean_Profit)
print('Median Profit:', median_Profit)
print('Maximum Profit:', max_Profit)
print('Minimum Profit:', min_Profit)
# Out:
# Mean Profit: 28.65689630778467
# Median Profit: 8.6665
# Maximum Profit: 8399.976
# Minimum Profit: -6599.978

# %%
mean_Profit = store_df['Profit'].mean()
median_Profit = store_df['Profit'].median()
max_Profit = store_df['Profit'].max()
min_Profit = store_df['Profit'].min()
print('Mean Profit:', mean_Profit)
print('Median Profit:', median_Profit)
print('Maximum Profit:', max_Profit)
print('Minimum Profit:', min_Profit)
# Out:
# Mean Profit: 28.65689630778467
# Median Profit: 8.6665
# Maximum Profit: 8399.976
# Minimum Profit: -6599.978

# %%
mean_Discount = store_df['Discount'].mean()
median_Discount = store_df['Discount'].median()
max_Discount =store_df['Discount'].max()
min_Discount = store_df['Discount'].min()
print('Mean Discount:', mean_Discount)
print('Median Discount:', median_Discount)
print('Maximum Discount:', max_Discount)
print('Minimum Discount:', min_Discount)
# Out:
# Mean Discount: 0.15620272163297977
# Median Discount: 0.2
# Maximum Discount: 0.8
# Minimum Discount: 0.0

# %%
correlation_matrix = np.corrcoef( store_df['Sales'],  store_df['Profit'])
sales_profit_correlation = correlation_matrix[0, 1]
print('Sales-Profit Correlation:', sales_profit_correlation)
# Out:
# Sales-Profit Correlation: 0.4790643497377062

# %%
#correlation between the columns:
store_df.corr()
# Out:
# <ipython-input-286-6628a221d426>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   store_df.corr()
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200795 -0.028190  0.479064
# Quantity  0.200795  1.000000  0.008623  0.066253
# Discount -0.028190  0.008623  1.000000 -0.219487
# Profit    0.479064  0.066253 -0.219487  1.000000

# %%
#covarianvce between the set of variables:
store_df.cov()
# Out:
# <ipython-input-287-655a8a03dba5>:2: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   store_df.cov()
#                   Sales    Quantity   Discount        Profit
# Sales     388434.455308  278.459923  -3.627228  69944.096586
# Quantity     278.459923    4.951113   0.003961     34.534769
# Discount      -3.627228    0.003961   0.042622    -10.615173
# Profit     69944.096586   34.534769 -10.615173  54877.798055

# %% [markdown]
# statistical analysis

# %%
#find the total sales of each company
store_df.groupby("Quantity")["Sales"].sum()
# Out:
# Quantity
# 1      53251.9345
# 2     289091.4798
# 3     422060.6007
# 4     323670.9944
# 5     415661.6965
# 6     207122.3214
# 7     239908.3659
# 8     117760.1760
# 9     128505.5901
# 10     24056.6640
# 11     15772.4820
# 12     14868.4080
# 13     32338.1890
# 14     13131.9580
# Name: Sales, dtype: float64

# %%
store_df.groupby("Category")["Sales"].sum()
# Out:
# Category
# Furniture          741999.7953
# Office Supplies    719047.0320
# Technology         836154.0330
# Name: Sales, dtype: float64

# %%
##efficiency of the sales man
store_df.groupby("Country")["Sales"].mean()
# Out:
# Country
# United States    229.858001
# Name: Sales, dtype: float64

# %%
store_df.groupby("Quantity")["Sales"].mean()
# Out:
# Quantity
# 1       59.234632
# 2      120.354488
# 3      175.201578
# 4      271.764059
# 5      337.936339
# 6      362.101960
# 7      395.888393
# 8      458.210802
# 9      498.083683
# 10     422.046737
# 11     463.896529
# 12     646.452522
# 13    1197.710704
# 14     452.826138
# Name: Sales, dtype: float64

# %% [markdown]
# # **visualisation** ***of*** ***Data***

# %%
store_df.groupby("Quantity")["Sales"].sum().plot.line()
# Out:
# <Axes: xlabel='Quantity'>

# %%
store_df.groupby("Quantity")["Sales"].sum().plot.bar()
# Out:
# <Axes: xlabel='Quantity'>

# %%
store_df.groupby("Quantity")["Discount"].sum().plot.bar()
# Out:
# <Axes: xlabel='Quantity'>

# %%
#sales analysis by discount
store_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Region        9994 non-null   object
#  6   Category      9994 non-null   object
#  7   Sub-Category  9994 non-null   object
#  8   Sales         9994 non-null   float64
#  9   Quantity      9994 non-null   int64
#  10  Discount      9994 non-null   float64
#  11  Profit        9994 non-null   float64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 937.1+ KB

# %%
store_df.groupby("State")["Sales"].sum().plot.bar()
# Out:
# <Axes: xlabel='State'>

# %%
store_df.groupby("Region")["Sales"].sum().plot.bar()
# Out:
# <Axes: xlabel='Region'>

# %%
df.groupby("Region")["Sales"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='Sales'>

# %%
df.groupby("Region")["Profit"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='Profit'>

# %%
store_df.groupby("Segment")["Sales"].sum().plot.bar()
# Out:
# <Axes: xlabel='Segment'>

# %%
store_df.groupby("State")["Profit"].sum().plot.bar()
# Out:
# <Axes: xlabel='State'>

# %%
store_df.groupby("Category")["Sales"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='Sales'>

# %%
store_df.groupby("Category")["Profit"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='Profit'>

# %%
plt.figure(figsize=(16,8))
plt.bar('Sub-Category','Category',data=store_df)
plt.show()

# %%
plt.figure(figsize=(12,10))
store_df['Sub-Category'].value_counts().plot.pie(autopct="%1.1f%%")
plt.show()

# %%
store_df.groupby('Sub-Category')['Profit','Sales'].agg(['sum']).plot.bar()
plt.title("Profits and sales per Sub-Category ")
plt.rcParams['figure.figsize']=[10,8]
plt.show()
# Out:
# <ipython-input-306-b2acbc09bc80>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   store_df.groupby('Sub-Category')['Profit','Sales'].agg(['sum']).plot.bar()

# %%
df.groupby("Region")["Sales"].sum().plot.pie(autopct="%1.0f%%")
# Out:
# <Axes: ylabel='Sales'>

# %% [markdown]
# **sales and profit region wise**

# %%
store_df.groupby('Region')['Profit',"Sales"].agg(['sum']).plot.bar()
plt.title("profit and sales per Region")
plt.rcParams['figure.figsize']=[10,8]
plt.show()
# Out:
# <ipython-input-308-1c37f14e3c01>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   store_df.groupby('Region')['Profit',"Sales"].agg(['sum']).plot.bar()

# %% [markdown]
# **count plot of sub-category**

# %%
print(store_df['Sub-Category'].value_counts())
plt.figure(figsize=(12,6))
sns.countplot(x=store_df['Sub-Category'])
plt.xticks(rotation=90)
plt.show()
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %% [markdown]
# **sales vs profit**

# %%
x = store_df['Sales'].values
y = store_df['Profit'].values

plt.scatter(x, y)
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.title('Sales vs. Profit')
plt.show()

# %% [markdown]
# **sales by region**

# %%
region_sales = store_df.groupby('Region')['Sales'].sum()
regions = region_sales.index.values
sales = region_sales.values

plt.plot(regions, sales)
plt.xlabel('Region')
plt.ylabel('Sales')
plt.title('Sales by Region')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **pair-plot of sub-category**

# %%
figsize=(15,10)
sns.pairplot(store_df,hue='Sub-Category')

# %% [markdown]
# **pair plot of data**

# %%
sns.pairplot(store_df)

# %% [markdown]
# **Sales and Profitability by Category and Sub-Category**

# %%
category_sales = df.groupby(['Category', 'Sub-Category'])['Sales'].sum().sort_values(ascending=False)
category_profit = df.groupby(['Category', 'Sub-Category'])['Profit'].sum().sort_values(ascending=False)

# %%
plt.figure(figsize=(12, 8))
category_sales.plot(kind='bar', color='y', label='Total Sales')
category_profit.plot(kind='bar', color='r', label='Total Profit')
plt.xlabel('Category, Sub-Category')
plt.ylabel('Amount (USD)')
plt.title('Top-Selling Categories and Sub-Categories')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %% [markdown]
# **Impact of Discounts on Profitability**

# %%
discount_profit = df.groupby('Discount')['Profit'].sum()

plt.figure(figsize=(8, 6))
discount_profit.plot(kind='bar', color='purple')
plt.xlabel('Discount')
plt.ylabel('Total Profit (USD)')
plt.title('Impact of Discounts on Profitability')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# **Sales distribution by country and region**

# %%
if 'Country' in df.columns and 'Region' in df.columns:
    geo_sales = df.groupby(['Country', 'Region'])['Sales'].sum()

    plt.figure(figsize=(10, 6))
    geo_sales.plot(kind='bar', color='b')
    plt.xlabel('Country, Region')
    plt.ylabel('Total Sales (USD)')
    plt.title('Sales Distribution by Country and Region')
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# **Customer Segmentation (if applicable, assuming column 'Segment' is present)**

# %%
# Step 6: Customer Segmentation (if applicable, assuming column 'Segment' is present)
if 'Segment' in df.columns:
    customer_segment_sales = df.groupby('Segment')['Sales'].sum()

    plt.figure(figsize=(8, 6))
    customer_segment_sales.plot(kind='bar', color='orange')
    plt.xlabel('Customer Segment')
    plt.ylabel('Total Sales (USD)')
    plt.title('Sales by Customer Segment')
    plt.xticks(rotation=0)
    plt.show()

# %% [markdown]
# **Loss-Making Transactions**

# %%
loss_transactions = df[df['Profit'] < 0]

plt.figure(figsize=(10, 6))
plt.scatter(loss_transactions['Sales'], loss_transactions['Profit'], color='r')
plt.xlabel('Sales (USD)')
plt.ylabel('Profit (USD)')
plt.title('Loss-Making Transactions')
plt.show()

# %%
grouped=pd.DataFrame(store_df.groupby(['Ship Mode','Segment','Category','Sub-Category','State','Region'])['Quantity', 'Discount','Sales','Profit'].sum().reset_index())

grouped
# Out:
# <ipython-input-320-7fde71c7ed47>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   grouped=pd.DataFrame(store_df.groupby(['Ship Mode','Segment','Category','Sub-Category','State','Region'])['Quantity', 'Discount','Sales','Profit'].sum().reset_index())
#            Ship Mode      Segment    Category Sub-Category       State  \
# 0        First Class     Consumer   Furniture    Bookcases     Arizona
# 1        First Class     Consumer   Furniture    Bookcases  California
# 2        First Class     Consumer   Furniture    Bookcases    Colorado
# 3        First Class     Consumer   Furniture    Bookcases     Florida
# 4        First Class     Consumer   Furniture    Bookcases     Georgia
# ...              ...          ...         ...          ...         ...
# 2978  Standard Class  Home Office  Technology       Phones       Texas
# 2979  Standard Class  Home Office  Technology       Phones     Vermont
# ...

# %% [markdown]
# Statistical summary of data

# %%
store_df.groupby('State').Profit.agg(['sum','mean','min','max','count','median','std','var'])
# Out:
#                              sum        mean        min        max  count  \
# State
# Alabama                5786.8253   94.865989     0.0000  1459.2000     61
# Arizona               -3427.9246  -15.303235  -814.4832   211.4955    224
# Arkansas               4008.6871   66.811452     1.4190   843.1706     60
# California            76381.3871   38.171608  -325.5720  1906.4850   2001
# Colorado              -6527.8579  -35.867351 -3399.9800   247.9960    182
# Connecticut            3511.4918   42.823071   -15.5826   294.6710     82
# Delaware               9977.3748  103.930988   -48.7839  5039.9856     96
# District of Columbia   1059.5893  105.958930     4.4344   648.5624     10
# Florida               -3399.3017   -8.875461 -1811.0784   327.5922    383
# Georgia               16250.0433   88.315453     0.1134  3177.4750    184
# Idaho                   826.7231   39.367767     1.1151   259.5297     21
# Illinois             -12607.8870  -25.625787 -2929.4845   874.9875    492
# ...
